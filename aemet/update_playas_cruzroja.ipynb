# %% [markdown]
# # Añadir longitud y latitud a las playas

# %%
import urllib, json
url = "http://www.cruzroja.es/crmaps/playas.do"
response = urllib.urlopen(url)
data = json.loads(response.read(),encoding='latin1')
print data
# Out:
# {u'resultado': u'OK', u'playas': [{u'latitud': u'36.393300', u'provi_auto_codigo': u'1', u'facultativos': u'0', u'provi_codigo': u'11', u'personas_evacuadas': u'0', u'bandera': u'V', u'patrones': u'1', u'conductores': u'0', u'munic_nummun': u'15', u'asistencia_sanitaria': u'0', u'fecha': u'16/07/2015', u'due': u'1', u'ayuda_bano': u'S', u'asistencia_embarcacion': u'0', u'nombre': u'SANCTI PETRI', u'motivo_bandera': u'1', u'centr_codigo': u'13906', u'personal_atencion_social': u'0', u'avisos_recomendaciones': u'0', u'cuando': u'D', u'ahogados_en_horario': u'0', u'asistencia_medusas': u'0', u'asistencia_muletas': u'0', u'socorristas_sanitario': u'0', u'cobertura_hasta': u'21:00', u'fecharevi': u'16/07/2015 13:34', u'estado': u'A', u'longitud': u'-6.209127', u'asistencia_silla': u'0', u'socorristas': u'3', u'personas_rescatadas': u'0', u'medusas': u'N', u'asistencia_menores': u'0', u'hasta': u'31/08/2015', u'codigo_diarios': u'444817', u'desde': u'01/07/2015', u'asistencia_social': u'0'
# ...
